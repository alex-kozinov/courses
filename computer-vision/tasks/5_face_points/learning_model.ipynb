# %% [markdown]
# # Дополнительная установка

# %%
MODEL_SAVE_DIR = "models/CV/face_points"
MOUNT_DIR = '/content/drive' # In case Colab Usage

# %%
# !rm detection.py

# %%
# !wget https://raw.githubusercontent.com/alex-kozinov/courses/master/computer-vision/tasks/5_face_points/detection.py?token=AC5LOYE7F4V3M5CYUJLNP23AEBIPU -O detection.py
# Out:
# --2021-01-31 20:43:53--  https://raw.githubusercontent.com/alex-kozinov/courses/master/computer-vision/tasks/5_face_points/detection.py?token=AC5LOYE7F4V3M5CYUJLNP23AEBIPU
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9536 (9.3K) [text/plain]
# Saving to: ‘detection.py’
#
# detection.py        100%[===================>]   9.31K  --.-KB/s    in 0s
#
# 2021-01-31 20:43:53 (86.9 MB/s) - ‘detection.py’ saved [9536/9536]

# %%
# !pip install -U git+https://github.com/albu/albumentations --no-cache-dir
# Out:
# ...
#   Cloning https://github.com/albu/albumentations to /tmp/pip-req-build-cq845iu9
#   Running command git clone -q https://github.com/albu/albumentations /tmp/pip-req-build-cq845iu9
# ...
#   Created wheel for albumentations: filename=albumentations-0.5.2-cp36-none-any.whl size=81844 sha256=51f45ed88d38808ba3746eddbe87e920847bb47c342302d6fd8b5d9f1cb468c4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-odrwtuit/wheels/45/8b/e4/2837bbcf517d00732b8e394f8646f22b8723ac00993230188b
# Successfully built albumentations
# ...
#   Found existing installation: albumentations 0.5.2
#     Uninstalling albumentations-0.5.2:
#       Successfully uninstalled albumentations-0.5.2
# ...

# %% [markdown]
# # Подключение библиотек

# %%
from detection import train_detector, detect, get_model
import os

try:
    from google.colab import files, drive
    
    USE_COLAB = True
except:
    USE_COLAB = False

if USE_COLAB:
    print("Don't forget to avoid disconnections:")
    print("""
function ClickConnect(){
    console.log("Clicking"); 
    document.querySelector("colab-connect-button").click() 
}
setInterval(ClickConnect,60000)
    """)
# Out:
# Don't forget to avoid disconnections:
#
# function ClickConnect(){
#     console.log("Clicking");
#     document.querySelector("colab-connect-button").click()
# }
# setInterval(ClickConnect,60000)

# %% [markdown]
# # Загрузка данных

# %%
if USE_COLAB:
    drive.mount(MOUNT_DIR)
    DRIVE_DIR = os.path.join(MOUNT_DIR, 'My Drive')
    print(f"Drive directory is {DRIVE_DIR}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive directory is /content/drive/My Drive

# %%
data_archive_path = os.path.join(DRIVE_DIR, 'datasets/CV2020/face_points/public_tests.zip')

# %%
# !rm -r ./public_tests

# %%
# !unzip -o "$data_archive_path" -d "./public_tests" > /dev/null

# %%
# !ls
# Out:
# detection.py  drive  public_tests  __pycache__	sample_data  segmentation.py

# %% [markdown]
# # Обучение модели

# %%
train_gt = './public_tests/00_test_img_input/train/gt.csv'
train_img_dir = './public_tests/00_test_img_input/train/images/'
checkpoint_dir = os.path.join(DRIVE_DIR, MODEL_SAVE_DIR) + '/'

# %%
# train_detector(train_gt, train_img_dir, checkpoint_dir=checkpoint_dir)

# %% [markdown]
# # Предсказание

# %%
# !ls public_tests/00_test_img_input/test
# Out:
# images

# %%
model = get_model()

# %%
model.load_weights(
    checkpoint_dir + "facepoints_model.hdf5"
)

# %%
detect(model, "public_tests/00_test_img_input/test/images")
# Out:
# {'00831.jpg': array([29.621553, 22.430433, 51.887844, 22.670923, 76.91087 , 25.694742,
#         98.247055, 28.966066, 33.359737, 34.35725 , 42.145767, 34.727985,
#         50.14391 , 35.90869 , 77.73185 , 39.307106, 86.079285, 40.00477 ,
#         94.09788 , 40.975975, 62.05697 , 63.26566 , 45.141926, 86.01203 ,
#         60.85687 , 87.22024 , 76.10525 , 89.24319 ], dtype=float32),
#  '01912.jpg': array([13.795235, 29.064276, 36.696693, 23.859804, 58.302097, 21.087605,
#         76.06309 , 17.879423, 20.637426, 36.070755, 28.93324 , 34.049324,
#         36.56435 , 33.61477 , 58.840042, 30.54291 , 65.51559 , 28.13099 ,
#         72.457695, 27.43015 , 55.747295, 52.388977, 38.776623, 70.60575 ,
#         54.85215 , 69.5398  , 66.589775, 65.712685], dtype=float32),
#  '05111.jpg': array([ 22.851456,  27.84533 ,  48.500275,  26.632061,  75.7265  ,
#          26.934715, 100.11677 ,  26.623085,  29.790298,  38.20565 ,
#          39.3505  ,  37.85865 ,  48.45944 ,  38.540913,  76.60557 ,
# ...

# %%
q
