# %% [markdown]
# # Assignment 1.2: Word2vec preprocessing (20 points)

# %% [markdown]
# Preprocessing is not the most exciting part of NLP, but it is still one of the most important ones. Your task is to preprocess raw text (you can use your own, or [this one](http://mattmahoney.net/dc/text8.zip). For this task text preprocessing mostly consists of:
#
# 1. cleaning (mostly, if your dataset is from social media or parsed from the internet)
# 1. tokenization
# 1. building the vocabulary and choosing its size. Use only high-frequency words, change all other words to UNK or handle it in your own manner. You can use `collections.Counter` for that.
# 1. assigning each token a number (numericalization). In other words, make word2index и index2word objects.
# 1. data structuring and batching - make X and y matrices generator for word2vec (explained in more details below)
#
# **ATTN!:** If you use your own data, please, attach a download link.
#
# Your goal is to make **Batcher** class which returns two numpy tensors with word indices. It should be possible to use one for word2vec training. You can implement batcher for Skip-Gram or CBOW architecture, the picture below can be helpful to remember the difference.
#
# ![text](https://raw.githubusercontent.com/deepmipt/deep-nlp-seminars/651804899d05b96fc72b9474404fab330365ca09/seminar_02/pics/architecture.png)
#
# There are several ways to do it right. Shapes could be `x_batch.shape = (batch_size, 2*window_size)`, `y_batch.shape = (batch_size,)` for CBOW or `(batch_size,)`, `(batch_size, 2*window_size)` for Skip-Gram. You should **not** do negative sampling here.
#
# They should be adequately parametrized: CBOW(window_size, ...), SkipGram(window_size, ...). You should implement only one batcher in this task; and it's up to you which one to chose.
#
# Useful links:
# 1. [Word2Vec Tutorial - The Skip-Gram Model](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/)
# 1. [Efficient Estimation of Word Representations in Vector Space](https://arxiv.org/pdf/1301.3781.pdf)
# 1. [Distributed Representations of Words and Phrases and their Compositionality](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf)
#
# You can write the code in this notebook, or in a separate file. It can be reused for the next task. The result of your work should represent that your batch has a proper structure (right shapes) and content (words should be from one context, not some random indices). To show that, translate indices back to words and print them to show something like this:
#
# ```
# text = ['first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including']
#
# window_size = 2
#
# # CBOW:
# indices_to_words(x_batch) = \
#         [['first', 'used', 'early', 'working'],
#         ['used', 'against', 'working', 'class'],
#         ['against', 'early', 'class', 'radicals'],
#         ['early', 'working', 'radicals', 'including']]
#
# indices_to_words(labels_batch) = ['against', 'early', 'working', 'class']
# ```

# %% [markdown]
# # Solution

# %% [markdown]
# ## Imports and constants

# %%
import numpy as np
from collections import Counter
from batcher import SkipGramBatcherBase, read_corpus


TEXT_PATH = 'data/text8'

# %% [markdown]
# ## Skip-Gram Batcher impletation

# %% [markdown]
# I will implement here only ```__next__``` function, because for next task we have to use a different one

# %%
class SkipGramBatcher(SkipGramBatcherBase):
    def __next__(self):
        if len(self._batchs_positions) < self._batch_size:
            raise StopIteration

        centrals = []
        neighbours = []        
        for i in range(self._batch_size):
            ind = self._batchs_positions.pop(0)
            c, n = self._get_word_indices(ind)
            centrals.append(c)
            neighbours.append(n)
        return np.array(centrals), np.vstack(neighbours)

# %% [markdown]
# ## Тesting

# %%
def test_batcher(text, window_size, batch_size, vocabulary_size=None):
    print('Testing for text: "{}"'.format(' '.join(text)))
    b = SkipGramBatcher(text, window_size, batch_size, vocabulary_size)
    print('Text after cleaning: "{}"'.format(' '.join(b._corpus)))
    for i, (centrals, neighbours) in enumerate(b):
        if i > 10:  #  test only 10 batches
            return
        print('Batch number {}:'.format(i))
        centrals = b.batch_to_words(centrals)
        neighbours = b.batch_to_words(neighbours)
        for j in range(len(centrals)):
            print('\tCentral word is [{}] and neighbours:'.format(centrals[j]))
            print('\t\t' + '\n\t\t'.join(neighbours[j]))

# %% [markdown]
# ### simple test

# %%
simple_text = ['first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including']

# %%
test_batcher(simple_text, 2, 2)
# Out:
# Testing for text: "first used against early working class radicals including"
# Text after cleaning: "first used against early working class radicals including"
# Batch number 0:
# 	Central word is [class] and neighbours:
# 		early
# 		working
# 		radicals
# 		including
# 	Central word is [against] and neighbours:
# 		first
# 		used
# 		early
# 		working
# Batch number 1:
# 	Central word is [working] and neighbours:
# 		against
# 		early
# 		class
# 		radicals
# 	Central word is [early] and neighbours:
# 		used
# 		against
# 		working
# 		class

# %%
test_batcher(simple_text, 1, 3)
# Out:
# Testing for text: "first used against early working class radicals including"
# Text after cleaning: "first used against early working class radicals including"
# Batch number 0:
# 	Central word is [working] and neighbours:
# 		early
# 		class
# 	Central word is [radicals] and neighbours:
# 		class
# 		including
# 	Central word is [early] and neighbours:
# 		against
# 		working
# Batch number 1:
# 	Central word is [against] and neighbours:
# 		used
# 		early
# 	Central word is [used] and neighbours:
# 		first
# 		against
# 	Central word is [class] and neighbours:
# 		working
# 		radicals

# %%
test_batcher(simple_text, 3, 1)
# Out:
# Testing for text: "first used against early working class radicals including"
# Text after cleaning: "first used against early working class radicals including"
# Batch number 0:
# 	Central word is [working] and neighbours:
# 		used
# 		against
# 		early
# 		class
# 		radicals
# 		including
# Batch number 1:
# 	Central word is [early] and neighbours:
# 		first
# 		used
# 		against
# 		working
# 		class
# 		radicals

# %% [markdown]
# ### test with small vocabulary

# %%
text = ['Can', 'you', 'can', 'a', 'can', 'as', 'a', 'Canner', 'can', 'can', 'a', 'can']

# %%
test_batcher(text, 3, 1, vocabulary_size=2)
# Out:
# Testing for text: "Can you can a can as a Canner can can a can"
# Text after cleaning: "<UNK> <UNK> can <UNK> can <UNK> <UNK> <UNK> can can <UNK> can"
# Batch number 0:
# 	Central word is [<UNK>] and neighbours:
# 		can
# 		<UNK>
# 		<UNK>
# 		can
# 		can
# 		<UNK>
# Batch number 1:
# 	Central word is [<UNK>] and neighbours:
# 		<UNK>
# 		<UNK>
# 		can
# 		can
# 		<UNK>
# 		<UNK>
# Batch number 2:
# 	Central word is [<UNK>] and neighbours:
# 		can
# 		<UNK>
# 		can
# 		<UNK>
# 		<UNK>
# 		can
# Batch number 3:
# 	Central word is [can] and neighbours:
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 		can
# 		<UNK>
# 		can
# Batch number 4:
# 	Central word is [can] and neighbours:
# 		<UNK>
# 		can
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 		<UNK>
# Batch number 5:
# 	Central word is [<UNK>] and neighbours:
# 		<UNK>
# 		can
# 		<UNK>
# 		<UNK>
# 		can
# 		can

# %%
test_batcher(text, 2, 2, vocabulary_size=1)
# Out:
# Testing for text: "Can you can a can as a Canner can can a can"
# Text after cleaning: "<UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK>"
# Batch number 0:
# 	Central word is [<UNK>] and neighbours:
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 	Central word is [<UNK>] and neighbours:
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 		<UNK>
# Batch number 1:
# 	Central word is [<UNK>] and neighbours:
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 	Central word is [<UNK>] and neighbours:
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 		<UNK>
# Batch number 2:
# 	Central word is [<UNK>] and neighbours:
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 	Central word is [<UNK>] and neighbours:
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 		<UNK>
# Batch number 3:
# 	Central word is [<UNK>] and neighbours:
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 	Central word is [<UNK>] and neighbours:
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 		<UNK>

# %% [markdown]
# ## Preprocessing real data

# %%
corpus = read_corpus(TEXT_PATH)

# %%
test_batcher(corpus, 5, 10)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Batch number 0:
# 	Central word is [the] and neighbours:
# 		jumpers
# 		who
# 		are
# 		caught
# 		in
# 		act
# 		may
# 		face
# 		charges
# 		of
# 	Central word is [with] and neighbours:
# 		surgery
# 		effects
# 		which
# 		were
# 		alleviated
# 		the
# 		administration
# 		of
# 		anesthesia
# 		others
# 	Central word is [as] and neighbours:
# 		they
# 		were
# 		no
# 		longer
# 		regarded
# 		a
# 		one
# 		hit
# 		wonder
# 		much
# 	Central word is [must] and neighbours:
# 		with
# 		ordinances
# 		are
# 		defined
# 		and
# 		be
# 		delivered
# 		verbatim
# 		while
# 		others
# 	Central word is [and] and neighbours:
# 		grave
# 		which
# 		he
# 		had
# 		dug
# 		in
# 		which
# 		he
# 		resided
# 		my
# 	Central word is [taunts] and neighbours:
# 		riddle
# 		superstition
# 		and
# 		popular
# 		belief
# 		xerox
# 		lore
# 		national
# 		or
# 		ethnic
# 	Central word is [community] and neighbours:
# 		university
# 		in
# 		st
# 		louis
# 		washtenaw
# 		college
# 		waterford
# 		regional
# 		technical
# 		college
# 	Central word is [united] and neighbours:
# 		ii
# 		military
# 		equipment
# 		of
# 		the
# 		states
# 		the
# 		klingon
# 		language
# 		or
# 	Central word is [bishop] and neighbours:
# 		three
# 		nine
# 		seven
# 		ce
# 		a
# 		was
# 		accused
# 		of
# 		instigating
# 		the
# 	Central word is [the] and neighbours:
# 		two
# 		zero
# 		zero
# 		zero
# 		boosted
# 		country
# 		s
# 		reserves
# 		to
# 		over
# Batch number 1:
# 	Central word is [documentary] and neighbours:
# 		by
# 		steven
# 		m
# 		martin
# 		the
# 		was
# 		a
# 		winner
# 		at
# 		the
# 	Central word is [other] and neighbours:
# 		important
# 		in
# 		number
# 		theory
# 		among
# 		properties
# 		all
# 		factorials
# 		are
# 		highly
# 	Central word is [zero] and neighbours:
# 		alumni
# 		as
# 		of
# 		two
# 		zero
# 		five
# 		cornell
# 		university
# 		counted
# 		over
# 	Central word is [fall] and neighbours:
# 		jews
# 		from
# 		spain
# 		after
# 		the
# 		of
# 		their
# 		last
# 		refuge
# 		there
# 	Central word is [associated] and neighbours:
# 		augmenting
# 		or
# 		decreasing
# 		the
# 		electrons
# 		with
# 		a
# 		particular
# 		atom
# 		according
# 	Central word is [one] and neighbours:
# 		people
# 		could
# 		be
# 		killed
# 		with
# 		bullet
# 		but
# 		it
# 		was
# 		too
# 	Central word is [movement] and neighbours:
# 		the
# 		luddites
# 		were
# 		a
# 		social
# 		of
# 		english
# 		workers
# 		in
# 		the
# 	Central word is [das] and neighbours:
# 		nine
# 		die
# 		spinnen
# 		two
# 		teil
# 		brillantenschiff
# 		spiders
# 		part
# 		two
# 		the
# 	Central word is [the] and neighbours:
# 		f
# 		r
# 		vollst
# 		ndigen
# 		unsinn
# 		journal
# 		for
# 		utter
# 		nonsense
# 		seven
# 	Central word is [the] and neighbours:
# 		m
# 		is
# 		the
# 		mean
# 		of
# 		distribution
# 		and
# 		the
# 		moment
# 		about
# Batch number 2:
# 	Central word is [of] and neighbours:
# 		its
# 		context
# 		a
# 		perfect
# 		process
# 		natural
# 		selection
# 		would
# 		not
# 		have
# 	Central word is [understanding] and neighbours:
# 		lyricist
# 		and
# 		are
# 		essential
# 		to
# 		his
# 		vision
# 		for
# 		musical
# 		performance
# 	Central word is [injustice] and neighbours:
# 		our
# 		right
# 		for
# 		struggle
# 		against
# 		maligned
# 		and
# 		our
# 		present
# 		existence
# 	Central word is [place] and neighbours:
# 		whose
# 		generation
# 		for
# 		eusebius
# 		took
# 		before
# 		time
# 		jesus
# 		is
# 		in
# 	Central word is [the] and neighbours:
# 		by
# 		cuyp
# 		is
# 		unmistakably
# 		masterful
# 		richly
# 		varnished
# 		medium
# 		refracts
# 		the
# 	Central word is [the] and neighbours:
# 		policy
# 		has
# 		become
# 		increasingly
# 		pragmatic
# 		twin
# 		pillars
# 		of
# 		the
# 		policy
# 	Central word is [in] and neighbours:
# 		threatens
# 		natural
# 		fisheries
# 		soil
# 		erosion
# 		rural
# 		areas
# 		a
# 		majority
# 		of
# 	Central word is [and] and neighbours:
# 		four
# 		two
# 		years
# 		for
# 		males
# 		four
# 		three
# 		three
# 		years
# 		for
# 	Central word is [nine] and neighbours:
# 		by
# 		dieterich
# 		abraxas
# 		one
# 		zero
# 		this
# 		book
# 		which
# 		may
# 		be
# 	Central word is [but] and neighbours:
# 		to
# 		earn
# 		a
# 		meagre
# 		income
# 		little
# 		of
# 		it
# 		came
# 		from
# Batch number 3:
# 	Central word is [loa] and neighbours:
# 		carbon
# 		dioxide
# 		amounts
# 		from
# 		mauna
# 		observatory
# 		show
# 		that
# 		co
# 		two
# 	Central word is [one] and neighbours:
# 		seven
# 		lup
# 		four
# 		two
# 		seven
# 		lup
# 		four
# 		nine
# 		nine
# 		two
# 	Central word is [in] and neighbours:
# 		indirectly
# 		affiliated
# 		to
# 		the
# 		group
# 		the
# 		one
# 		three
# 		th
# 		century
# 	Central word is [became] and neighbours:
# 		the
# 		indian
# 		parliament
# 		himachal
# 		pradesh
# 		a
# 		union
# 		territory
# 		on
# 		november
# 	Central word is [may] and neighbours:
# 		require
# 		that
# 		certain
# 		executive
# 		powers
# 		only
# 		be
# 		exercised
# 		in
# 		conjunction
# 	Central word is [for] and neighbours:
# 		and
# 		a
# 		centralised
# 		email
# 		interface
# 		querying
# 		the
# 		database
# 		had
# 		been
# 	Central word is [random] and neighbours:
# 		the
# 		details
# 		are
# 		meaningful
# 		never
# 		writing
# 		in
# 		greek
# 		eusebius
# 		of
# 	Central word is [reformer] and neighbours:
# 		martin
# 		luther
# 		german
# 		reformer
# 		and
# 		of
# 		germany
# 		one
# 		five
# 		two
# 	Central word is [groups] and neighbours:
# 		is
# 		widely
# 		used
# 		by
# 		immigrant
# 		in
# 		luxembourg
# 		germany
# 		belgium
# 		the
# 	Central word is [it] and neighbours:
# 		single
# 		seat
# 		set
# 		aside
# 		for
# 		this
# 		was
# 		the
# 		first
# 		uk
# Batch number 4:
# 	Central word is [and] and neighbours:
# 		forming
# 		water
# 		from
# 		the
# 		hydroxyl
# 		hydrogen
# 		and
# 		the
# 		polymer
# 		polyester
# 	Central word is [quoted] and neighbours:
# 		both
# 		parties
# 		danforth
# 		was
# 		once
# 		as
# 		saying
# 		he
# 		joined
# 		the
# 	Central word is [zero] and neighbours:
# 		nine
# 		two
# 		three
# 		two
# 		zero
# 		five
# 		peter
# 		glotz
# 		german
# 		social
# 	Central word is [grown] and neighbours:
# 		she
# 		once
# 		admired
# 		to
# 		have
# 		into
# 		a
# 		tired
# 		old
# 		man
# 	Central word is [bluetooth] and neighbours:
# 		defined
# 		and
# 		adopted
# 		by
# 		the
# 		sig
# 		advanced
# 		audio
# 		distribution
# 		profile
# 	Central word is [his] and neighbours:
# 		face
# 		with
# 		the
# 		reality
# 		of
# 		condition
# 		the
# 		starting
# 		point
# 		for
# 	Central word is [j] and neighbours:
# 		slotj
# 		key
# 		modulus
# 		numslots
# 		if
# 		i
# 		and
# 		k
# 		j
# 		or
# 	Central word is [a] and neighbours:
# 		to
# 		an
# 		internet
# 		user
# 		as
# 		troll
# 		might
# 		not
# 		be
# 		based
# 	Central word is [ease] and neighbours:
# 		within
# 		the
# 		amiga
# 		community
# 		its
# 		of
# 		use
# 		made
# 		it
# 		especially
# 	Central word is [toward] and neighbours:
# 		shuttle
# 		challenger
# 		is
# 		depicted
# 		ascending
# 		the
# 		heavens
# 		in
# 		search
# 		of
# Batch number 5:
# 	Central word is [lcd] and neighbours:
# 		dlp
# 		most
# 		display
# 		technologies
# 		especially
# 		have
# 		an
# 		inherent
# 		misregistration
# 		of
# 	Central word is [the] and neighbours:
# 		measured
# 		at
# 		a
# 		standard
# 		distance
# 		values
# 		obtained
# 		are
# 		compared
# 		with
# 	Central word is [five] and neighbours:
# 		one
# 		million
# 		places
# 		and
# 		two
# 		or
# 		one
# 		zero
# 		million
# 		places
# 	Central word is [new] and neighbours:
# 		book
# 		the
# 		new
# 		grove
# 		haydn
# 		york
# 		macmillan
# 		two
# 		zero
# 		zero
# 	Central word is [day] and neighbours:
# 		style
# 		dates
# 		d
# 		m
# 		y
# 		month
# 		year
# 		is
# 		used
# 		by
# 	Central word is [one] and neighbours:
# 		seven
# 		zero
# 		zero
# 		jpg
# 		a
# 		nine
# 		three
# 		nine
# 		dkw
# 		f
# 	Central word is [utilities] and neighbours:
# 		of
# 		the
# 		large
# 		state
# 		owned
# 		latvia
# 		is
# 		a
# 		member
# 		of
# 	Central word is [house] and neighbours:
# 		death
# 		in
# 		his
# 		post
# 		white
# 		years
# 		coolidge
# 		served
# 		as
# 		chairman
# 	Central word is [two] and neighbours:
# 		in
# 		january
# 		the
# 		coolest
# 		above
# 		zero
# 		zero
# 		zero
# 		meters
# 		temperatures
# 	Central word is [control] and neighbours:
# 		kennedy
# 		was
# 		prescribed
# 		steroids
# 		to
# 		his
# 		colitis
# 		which
# 		only
# 		heightened
# Batch number 6:
# 	Central word is [e] and neighbours:
# 		bridge
# 		arch
# 		or
# 		dome
# 		and
# 		arth
# 		a
# 		cliff
# 		or
# 		other
# 	Central word is [most] and neighbours:
# 		to
# 		morrison
# 		one
# 		of
# 		the
# 		important
# 		events
# 		of
# 		his
# 		life
# 	Central word is [a] and neighbours:
# 		pizan
# 		s
# 		ability
# 		to
# 		create
# 		female
# 		oriented
# 		dialogue
# 		in
# 		her
# 	Central word is [the] and neighbours:
# 		when
# 		they
# 		arrived
# 		at
# 		kuwait
# 		bani
# 		utub
# 		found
# 		a
# 		small
# 	Central word is [very] and neighbours:
# 		to
# 		rotate
# 		clockwise
# 		and
# 		a
# 		small
# 		number
# 		of
# 		skaters
# 		can
# 	Central word is [symptoms] and neighbours:
# 		a
# 		level
# 		where
# 		they
# 		cause
# 		the
# 		microorganisms
# 		involved
# 		in
# 		bv
# 	Central word is [comparative] and neighbours:
# 		accepted
# 		a
# 		medical
# 		professorship
# 		of
# 		anatomy
# 		at
# 		charlestown
# 		massachusetts
# 		but
# 	Central word is [nowadays] and neighbours:
# 		scheme
# 		that
# 		is
# 		still
# 		used
# 		in
# 		parallel
# 		with
# 		proper
# 		moon
# 	Central word is [a] and neighbours:
# 		finds
# 		a
# 		direct
# 		development
# 		with
# 		strong
# 		reformatory
# 		tendency
# 		this
# 		was
# 	Central word is [isolated] and neighbours:
# 		two
# 		o
# 		three
# 		was
# 		independently
# 		in
# 		one
# 		nine
# 		zero
# 		five
# Batch number 7:
# 	Central word is [storing] and neighbours:
# 		metadata
# 		a
# 		final
# 		way
# 		of
# 		the
# 		format
# 		of
# 		a
# 		file
# 	Central word is [five] and neighbours:
# 		headquarters
# 		marine
# 		corps
# 		on
# 		august
# 		one
# 		nine
# 		nine
# 		one
# 		he
# 	Central word is [times] and neighbours:
# 		five
# 		i
# 		died
# 		a
# 		thousand
# 		one
# 		nine
# 		five
# 		five
# 		giant
# 	Central word is [source] and neighbours:
# 		hydrogen
# 		is
# 		not
# 		a
# 		primary
# 		of
# 		energy
# 		it
# 		is
# 		only
# 	Central word is [our] and neighbours:
# 		dialogue
# 		these
# 		days
# 		this
# 		is
# 		first
# 		attempt
# 		to
# 		move
# 		beyond
# 	Central word is [one] and neighbours:
# 		day
# 		is
# 		on
# 		august
# 		three
# 		st
# 		external
# 		links
# 		irelandseye
# 		com
# 	Central word is [eat] and neighbours:
# 		a
# 		carbon
# 		based
# 		lifeform
# 		could
# 		coal
# 		however
# 		if
# 		they
# 		were
# 	Central word is [seven] and neighbours:
# 		nine
# 		nine
# 		five
# 		isbn
# 		zero
# 		eight
# 		six
# 		seven
# 		zero
# 		one
# 	Central word is [of] and neighbours:
# 		prior
# 		year
# 		and
# 		an
# 		increase
# 		two
# 		one
# 		three
# 		three
# 		zero
# 	Central word is [or] and neighbours:
# 		of
# 		such
# 		aesthetic
# 		religious
# 		political
# 		economic
# 		treasures
# 		rather
# 		than
# 		with
# Batch number 8:
# 	Central word is [four] and neighbours:
# 		atari
# 		vic
# 		apple
# 		commodore
# 		six
# 		and
# 		pet
# 		cbm
# 		computers
# 		or
# 	Central word is [classical] and neighbours:
# 		identified
# 		within
# 		the
# 		experimental
# 		and
# 		or
# 		art
# 		traditions
# 		still
# 		working
# 	Central word is [bhawan] and neighbours:
# 		krishna
# 		anand
# 		benares
# 		bharat
# 		kala
# 		one
# 		nine
# 		eight
# 		one
# 		pp
# 	Central word is [that] and neighbours:
# 		can
# 		have
# 		a
# 		false
# 		edge
# 		can
# 		be
# 		sharpened
# 		to
# 		make
# 	Central word is [a] and neighbours:
# 		isot
# 		online
# 		rpg
# 		uchronia
# 		has
# 		good
# 		introduction
# 		to
# 		the
# 		topic
# 	Central word is [to] and neighbours:
# 		mentioned
# 		a
# 		son
# 		being
# 		born
# 		stalin
# 		and
# 		his
# 		common
# 		law
# 	Central word is [a] and neighbours:
# 		friend
# 		and
# 		ally
# 		paid
# 		off
# 		quarter
# 		of
# 		his
# 		two
# 		zero
# 	Central word is [the] and neighbours:
# 		be
# 		carefully
# 		designed
# 		to
# 		achieve
# 		desired
# 		effect
# 		and
# 		the
# 		underlying
# 	Central word is [in] and neighbours:
# 		india
# 		feast
# 		of
# 		divina
# 		pastora
# 		barquisimeto
# 		venezuela
# 		day
# 		of
# 		st
# 	Central word is [the] and neighbours:
# 		nazi
# 		and
# 		direct
# 		responsibility
# 		for
# 		holocaust
# 		hermann
# 		knew
# 		he
# 		had
# Batch number 9:
# 	Central word is [on] and neighbours:
# 		was
# 		also
# 		made
# 		and
# 		shown
# 		vh
# 		one
# 		in
# 		that
# 		same
# 	Central word is [responsible] and neighbours:
# 		kahan
# 		commission
# 		found
# 		him
# 		personally
# 		for
# 		his
# 		disregard
# 		of
# 		the
# 	Central word is [era] and neighbours:
# 		in
# 		comerica
# 		park
# 		the
# 		cobb
# 		in
# 		one
# 		nine
# 		zero
# 		five
# 	Central word is [dikty] and neighbours:
# 		four
# 		also
# 		in
# 		t
# 		e
# 		s
# 		best
# 		science
# 		fiction
# 		stories
# 	Central word is [it] and neighbours:
# 		complete
# 		and
# 		stable
# 		operating
# 		system
# 		also
# 		moved
# 		the
# 		mac
# 		to
# 	Central word is [against] and neighbours:
# 		best
# 		known
# 		for
# 		her
# 		fight
# 		the
# 		equal
# 		rights
# 		amendment
# 		first
# 	Central word is [zero] and neighbours:
# 		rip
# 		it
# 		up
# 		six
# 		eight
# 		eight
# 		one
# 		nine
# 		five
# 		six
# 	Central word is [languages] and neighbours:
# 		freer
# 		than
# 		in
# 		the
# 		control
# 		is
# 		more
# 		restricted
# 		than
# 		in
# 	Central word is [by] and neighbours:
# 		songs
# 		in
# 		those
# 		shows
# 		composed
# 		styne
# 		are
# 		i
# 		still
# 		get
# 	Central word is [tirthankaras] and neighbours:
# 		such
# 		that
# 		twenty
# 		three
# 		more
# 		came
# 		into
# 		the
# 		world
# 		to
# Batch number 10:
# 	Central word is [in] and neighbours:
# 		elevated
# 		in
# 		various
# 		characteristic
# 		patterns
# 		several
# 		types
# 		of
# 		organic
# 		aciduria
# 	Central word is [september] and neighbours:
# 		the
# 		subsequent
# 		years
# 		on
# 		one
# 		one
# 		nine
# 		nine
# 		nine
# 		the
# 	Central word is [replacing] and neighbours:
# 		civilian
# 		control
# 		over
# 		the
# 		army
# 		a
# 		number
# 		of
# 		senior
# 		officers
# 	Central word is [also] and neighbours:
# 		poor
# 		you
# 		re
# 		crazy
# 		see
# 		list
# 		of
# 		people
# 		widely
# 		considered
# 	Central word is [to] and neighbours:
# 		from
# 		one
# 		nine
# 		one
# 		zero
# 		one
# 		nine
# 		one
# 		four
# 		in
# 	Central word is [not] and neighbours:
# 		period
# 		of
# 		jahiliyyah
# 		she
# 		could
# 		have
# 		been
# 		less
# 		than
# 		one
# 	Central word is [yugoslavia] and neighbours:
# 		serbia
# 		and
# 		montenegro
# 		history
# 		of
# 		history
# 		of
# 		the
# 		balkans
# 		montenegrin
# 	Central word is [as] and neighbours:
# 		spread
# 		out
# 		roughly
# 		as
# 		wide
# 		the
# 		cat
# 		s
# 		body
# 		making
# 	Central word is [by] and neighbours:
# 		black
# 		crook
# 		with
# 		a
# 		book
# 		charles
# 		m
# 		barras
# 		and
# 		musical
# 	Central word is [luftwaffe] and neighbours:
# 		german
# 		world
# 		war
# 		ii
# 		people
# 		generals
# 		and
# 		leaders
# 		nazi
# 		leaders
