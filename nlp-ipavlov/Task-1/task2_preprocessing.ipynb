# %% [markdown]
# # Assignment 1.2: Word2vec preprocessing (20 points)

# %% [markdown]
# Preprocessing is not the most exciting part of NLP, but it is still one of the most important ones. Your task is to preprocess raw text (you can use your own, or [this one](http://mattmahoney.net/dc/text8.zip). For this task text preprocessing mostly consists of:
#
# 1. cleaning (mostly, if your dataset is from social media or parsed from the internet)
# 1. tokenization
# 1. building the vocabulary and choosing its size. Use only high-frequency words, change all other words to UNK or handle it in your own manner. You can use `collections.Counter` for that.
# 1. assigning each token a number (numericalization). In other words, make word2index и index2word objects.
# 1. data structuring and batching - make X and y matrices generator for word2vec (explained in more details below)
#
# **ATTN!:** If you use your own data, please, attach a download link.
#
# Your goal is to make **Batcher** class which returns two numpy tensors with word indices. It should be possible to use one for word2vec training. You can implement batcher for Skip-Gram or CBOW architecture, the picture below can be helpful to remember the difference.
#
# ![text](https://raw.githubusercontent.com/deepmipt/deep-nlp-seminars/651804899d05b96fc72b9474404fab330365ca09/seminar_02/pics/architecture.png)
#
# There are several ways to do it right. Shapes could be `x_batch.shape = (batch_size, 2*window_size)`, `y_batch.shape = (batch_size,)` for CBOW or `(batch_size,)`, `(batch_size, 2*window_size)` for Skip-Gram. You should **not** do negative sampling here.
#
# They should be adequately parametrized: CBOW(window_size, ...), SkipGram(window_size, ...). You should implement only one batcher in this task; and it's up to you which one to chose.
#
# Useful links:
# 1. [Word2Vec Tutorial - The Skip-Gram Model](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/)
# 1. [Efficient Estimation of Word Representations in Vector Space](https://arxiv.org/pdf/1301.3781.pdf)
# 1. [Distributed Representations of Words and Phrases and their Compositionality](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf)
#
# You can write the code in this notebook, or in a separate file. It can be reused for the next task. The result of your work should represent that your batch has a proper structure (right shapes) and content (words should be from one context, not some random indices). To show that, translate indices back to words and print them to show something like this:
#
# ```
# text = ['first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including']
#
# window_size = 2
#
# # CBOW:
# indices_to_words(x_batch) = \
#         [['first', 'used', 'early', 'working'],
#         ['used', 'against', 'working', 'class'],
#         ['against', 'early', 'class', 'radicals'],
#         ['early', 'working', 'radicals', 'including']]
#
# indices_to_words(labels_batch) = ['against', 'early', 'working', 'class']
# ```

# %% [markdown]
# # Solution

# %% [markdown]
# ## Imports and constants

# %%
import numpy as np
from collections import Counter
from batcher import SkipGramBatcherBase, read_corpus


TEXT_PATH = 'data/text8'

# %% [markdown]
# ## Skip-Gram Batcher impletation

# %% [markdown]
# I will implement here only ```__next__``` function, because for next task we have to use a different one

# %%
class SkipGramBatcher(SkipGramBatcherBase):
    def __next__(self):
        """ Return next batch of words with order specified in self._permuted_indxs
            Return:
                centrals (list): batch with central words. The length is (batch_size)
                neighbours (list of lists): batch with neighbour words. The size is (batch_size, 2*window_size)
        """
        centrals, neighbours = self._get_next_batch()
        if centrals is None or neighbours is None:
            raise StopIteration
        
        return centrals, neighbours

# %% [markdown]
# ## Тesting

# %%
def test_batcher(text, window_size, batch_size, vocabulary_size=None):
    print('Testing for text: "{}"'.format(' '.join(text)))
    b = SkipGramBatcher(text, window_size, batch_size, vocabulary_size)
    print('Text after cleaning: "{}"'.format(' '.join(b._corpus)))
    for i, (centrals, neighbours) in enumerate(b):
        if i > 10:  #  test only 10 batches
            return
        print('Batch number {}:'.format(i))
        centrals = b.tokens_to_words(centrals)
        neighbours = b.tokens_to_words(neighbours)
        for j in range(len(centrals)):
            print('\tCentral word is [{}] and neighbours:'.format(centrals[j]))
            print('\t\t' + '\n\t\t'.join(neighbours[j]))

# %% [markdown]
# ### simple test

# %%
simple_text = ['first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including']

# %%
test_batcher(simple_text, 2, 2)
# Out:
# Testing for text: "first used against early working class radicals including"
# Text after cleaning: "first used against early working class radicals including"
# Batch number 0:
# 	Central word is [early] and neighbours:
# 		used
# 		against
# 		working
# 		class
# 	Central word is [against] and neighbours:
# 		first
# 		used
# 		early
# 		working
# Batch number 1:
# 	Central word is [class] and neighbours:
# 		early
# 		working
# 		radicals
# 		including
# 	Central word is [working] and neighbours:
# 		against
# 		early
# 		class
# 		radicals

# %%
test_batcher(simple_text, 1, 3)
# Out:
# Testing for text: "first used against early working class radicals including"
# Text after cleaning: "first used against early working class radicals including"
# Batch number 0:
# 	Central word is [used] and neighbours:
# 		first
# 		against
# 	Central word is [against] and neighbours:
# 		used
# 		early
# 	Central word is [class] and neighbours:
# 		working
# 		radicals
# Batch number 1:
# 	Central word is [radicals] and neighbours:
# 		class
# 		including
# 	Central word is [early] and neighbours:
# 		against
# 		working
# 	Central word is [working] and neighbours:
# 		early
# 		class

# %%
test_batcher(simple_text, 3, 1)
# Out:
# Testing for text: "first used against early working class radicals including"
# Text after cleaning: "first used against early working class radicals including"
# Batch number 0:
# 	Central word is [working] and neighbours:
# 		used
# 		against
# 		early
# 		class
# 		radicals
# 		including
# Batch number 1:
# 	Central word is [early] and neighbours:
# 		first
# 		used
# 		against
# 		working
# 		class
# 		radicals

# %% [markdown]
# ### test with small vocabulary

# %%
text = ['Can', 'you', 'can', 'a', 'can', 'as', 'a', 'Canner', 'can', 'can', 'a', 'can']

# %%
test_batcher(text, 3, 1, vocabulary_size=2)
# Out:
# Testing for text: "Can you can a can as a Canner can can a can"
# Text after cleaning: "<UNK> <UNK> can <UNK> can <UNK> <UNK> <UNK> can can <UNK> can"
# Batch number 0:
# 	Central word is [can] and neighbours:
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 		can
# 		<UNK>
# 		can
# Batch number 1:
# 	Central word is [<UNK>] and neighbours:
# 		can
# 		<UNK>
# 		<UNK>
# 		can
# 		can
# 		<UNK>
# Batch number 2:
# 	Central word is [<UNK>] and neighbours:
# 		<UNK>
# 		can
# 		<UNK>
# 		<UNK>
# 		can
# 		can
# Batch number 3:
# 	Central word is [<UNK>] and neighbours:
# 		can
# 		<UNK>
# 		can
# 		<UNK>
# 		<UNK>
# 		can
# Batch number 4:
# 	Central word is [<UNK>] and neighbours:
# 		<UNK>
# 		<UNK>
# 		can
# 		can
# 		<UNK>
# 		<UNK>
# Batch number 5:
# 	Central word is [can] and neighbours:
# 		<UNK>
# 		can
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 		<UNK>

# %%
test_batcher(text, 2, 2, vocabulary_size=1)
# Out:
# Testing for text: "Can you can a can as a Canner can can a can"
# Text after cleaning: "<UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK>"
# Batch number 0:
# 	Central word is [<UNK>] and neighbours:
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 	Central word is [<UNK>] and neighbours:
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 		<UNK>
# Batch number 1:
# 	Central word is [<UNK>] and neighbours:
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 	Central word is [<UNK>] and neighbours:
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 		<UNK>
# Batch number 2:
# 	Central word is [<UNK>] and neighbours:
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 	Central word is [<UNK>] and neighbours:
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 		<UNK>
# Batch number 3:
# 	Central word is [<UNK>] and neighbours:
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 	Central word is [<UNK>] and neighbours:
# 		<UNK>
# 		<UNK>
# 		<UNK>
# 		<UNK>

# %% [markdown]
# ## Preprocessing real data

# %%
corpus = read_corpus(TEXT_PATH)

# %%
test_batcher(corpus, 5, 10)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Batch number 0:
# 	Central word is [after] and neighbours:
# 		dandy
# 		s
# 		career
# 		in
# 		venice
# 		world
# 		war
# 		i
# 		the
# 		diva
# 	Central word is [spain] and neighbours:
# 		of
# 		europe
# 		arab
# 		colonization
# 		of
# 		soviet
# 		colonization
# 		of
# 		eastern
# 		poland
# 	Central word is [folk] and neighbours:
# 		ly
# 		and
# 		together
# 		they
# 		collected
# 		music
# 		from
# 		the
# 		region
# 		this
# 	Central word is [formula] and neighbours:
# 		number
# 		rydberg
# 		formula
# 		the
# 		rydberg
# 		describes
# 		the
# 		transitions
# 		or
# 		quantum
# 	Central word is [college] and neighbours:
# 		so
# 		called
# 		smokers
# 		at
# 		pembroke
# 		include
# 		sketches
# 		and
# 		performances
# 		by
# 	Central word is [the] and neighbours:
# 		the
# 		blessed
# 		virgin
# 		mary
# 		cradling
# 		lifeless
# 		body
# 		of
# 		jesus
# 		mourning
# 	Central word is [the] and neighbours:
# 		several
# 		hits
# 		the
# 		name
# 		of
# 		game
# 		and
# 		take
# 		a
# 		chance
# 	Central word is [the] and neighbours:
# 		festival
# 		which
# 		takes
# 		place
# 		during
# 		last
# 		week
# 		of
# 		march
# 		the
# 	Central word is [from] and neighbours:
# 		it
# 		when
# 		it
# 		was
# 		snatched
# 		him
# 		he
# 		was
# 		transferred
# 		to
# 	Central word is [moved] and neighbours:
# 		s
# 		daughter
# 		by
# 		byron
# 		shelley
# 		his
# 		menage
# 		from
# 		place
# 		to
# Batch number 1:
# 	Central word is [history] and neighbours:
# 		six
# 		seven
# 		five
# 		six
# 		a
# 		of
# 		britain
# 		the
# 		complete
# 		collection
# 	Central word is [money] and neighbours:
# 		but
# 		time
# 		is
# 		money
# 		time
# 		which
# 		implies
# 		girls
# 		money
# 		money
# 	Central word is [four] and neighbours:
# 		and
# 		technical
# 		assistance
# 		agriculture
# 		contributes
# 		zero
# 		to
# 		gdp
# 		employs
# 		eight
# 	Central word is [the] and neighbours:
# 		first
# 		subsidiary
# 		aspect
# 		was
# 		that
# 		general
# 		strike
# 		however
# 		might
# 		be
# 	Central word is [actions] and neighbours:
# 		to
# 		attribute
# 		to
# 		al
# 		qaedaism
# 		that
# 		might
# 		not
# 		be
# 		directly
# 	Central word is [still] and neighbours:
# 		eight
# 		some
# 		historians
# 		even
# 		revisionists
# 		criticise
# 		the
# 		british
# 		high
# 		command
# 	Central word is [passed] and neighbours:
# 		literature
# 		at
# 		one
# 		seven
# 		jarry
# 		his
# 		baccalaur
# 		at
# 		and
# 		moved
# 	Central word is [that] and neighbours:
# 		instance
# 		the
# 		fairly
# 		common
# 		assertion
# 		tonality
# 		is
# 		a
# 		universal
# 		of
# 	Central word is [metres] and neighbours:
# 		threshold
# 		of
# 		one
# 		six
# 		five
# 		but
# 		is
# 		still
# 		hit
# 		by
# 	Central word is [the] and neighbours:
# 		bound
# 		to
# 		the
# 		proton
# 		by
# 		coulomb
# 		force
# 		the
# 		hydrogen
# 		atom
# Batch number 2:
# 	Central word is [assess] and neighbours:
# 		to
# 		describe
# 		and
# 		try
# 		to
# 		it
# 		was
# 		the
# 		french
# 		philosophe
# 	Central word is [plutarch] and neighbours:
# 		accounts
# 		are
# 		by
# 		arrian
# 		curtius
# 		diodorus
# 		and
# 		justin
# 		anabasis
# 		alexandri
# 	Central word is [vocational] and neighbours:
# 		institutes
# 		for
# 		primary
# 		secondary
# 		technical
# 		and
# 		adult
# 		education
# 		born
# 		in
# 	Central word is [six] and neighbours:
# 		five
# 		seven
# 		d
# 		two
# 		six
# 		m
# 		two
# 		four
# 		zero
# 		ep
# 	Central word is [other] and neighbours:
# 		always
# 		followed
# 		by
# 		vowels
# 		or
# 		voiced
# 		sounds
# 		indeed
# 		in
# 		eastern
# 	Central word is [three] and neighbours:
# 		km
# 		one
# 		five
# 		zero
# 		five
# 		mi
# 		there
# 		are
# 		one
# 		seven
# 	Central word is [as] and neighbours:
# 		held
# 		by
# 		the
# 		union
# 		army
# 		contraband
# 		of
# 		war
# 		in
# 		contraband
# 	Central word is [large] and neighbours:
# 		alien
# 		retaliated
# 		by
# 		dropping
# 		a
# 		boulder
# 		on
# 		xavier
# 		s
# 		legs
# 	Central word is [change] and neighbours:
# 		the
# 		diffusion
# 		volume
# 		does
# 		not
# 		with
# 		respect
# 		to
# 		time
# 		jin
# 	Central word is [downtown] and neighbours:
# 		concurrent
# 		juried
# 		fairs
# 		held
# 		on
# 		streets
# 		began
# 		in
# 		one
# 		nine
# Batch number 3:
# 	Central word is [molecular] and neighbours:
# 		if
# 		not
# 		the
# 		dominant
# 		theoretical
# 		biologist
# 		proof
# 		that
# 		the
# 		genetic
# 	Central word is [codex] and neighbours:
# 		codex
# 		usserianus
# 		primus
# 		codex
# 		vaticanus
# 		wallerstein
# 		codex
# 		zamoscianus
# 		codex
# 		zouche
# 	Central word is [latinos] and neighbours:
# 		heritage
# 		is
# 		arguably
# 		improperly
# 		called
# 		in
# 		american
# 		english
# 		outside
# 		of
# 	Central word is [distance] and neighbours:
# 		advanced
# 		extraterrestrial
# 		civilization
# 		within
# 		communication
# 		of
# 		earth
# 		refer
# 		to
# 		this
# 	Central word is [to] and neighbours:
# 		can
# 		interact
# 		with
# 		synaptic
# 		input
# 		alter
# 		the
# 		synaptic
# 		activity
# 		the
# 	Central word is [is] and neighbours:
# 		an
# 		identification
# 		of
# 		the
# 		two
# 		very
# 		questionable
# 		epimenides
# 		was
# 		a
# 	Central word is [is] and neighbours:
# 		understanding
# 		of
# 		human
# 		visual
# 		perception
# 		valuable
# 		to
# 		rendering
# 		this
# 		is
# 	Central word is [in] and neighbours:
# 		six
# 		continents
# 		and
# 		consular
# 		posts
# 		two
# 		countries
# 		that
# 		are
# 		not
# 	Central word is [to] and neighbours:
# 		of
# 		lech
# 		walesa
# 		britannica
# 		guide
# 		the
# 		nobel
# 		prizes
# 		lech
# 		walesa
# 	Central word is [locally] and neighbours:
# 		and
# 		chickens
# 		are
# 		largely
# 		produced
# 		but
# 		most
# 		of
# 		brunei
# 		s
# Batch number 4:
# 	Central word is [pioneer] and neighbours:
# 		railway
# 		in
# 		north
# 		america
# 		to
# 		ac
# 		traction
# 		locomotives
# 		in
# 		one
# 	Central word is [may] and neighbours:
# 		know
# 		i
# 		was
# 		here
# 		they
# 		not
# 		know
# 		or
# 		care
# 		who
# 	Central word is [to] and neighbours:
# 		meeting
# 		but
# 		is
# 		sometimes
# 		used
# 		refer
# 		to
# 		a
# 		building
# 		or
# 	Central word is [other] and neighbours:
# 		print
# 		however
# 		there
# 		are
# 		many
# 		books
# 		available
# 		covering
# 		the
# 		same
# 	Central word is [europe] and neighbours:
# 		lemkos
# 		mountain
# 		people
# 		of
# 		central
# 		lenca
# 		lezgis
# 		dagestani
# 		lhoba
# 		li
# 	Central word is [reprinted] and neighbours:
# 		printed
# 		one
# 		eight
# 		nine
# 		nine
# 		one
# 		nine
# 		seven
# 		one
# 		and
# 	Central word is [elements] and neighbours:
# 		the
# 		evangelical
# 		wing
# 		though
# 		all
# 		within
# 		the
# 		anglican
# 		communion
# 		recite
# 	Central word is [the] and neighbours:
# 		some
# 		arguments
# 		by
# 		proponents
# 		of
# 		paleolithic
# 		diet
# 		who
# 		argue
# 		that
# 	Central word is [six] and neighbours:
# 		six
# 		zero
# 		five
# 		system
# 		software
# 		zero
# 		six
# 		never
# 		released
# 		system
# 	Central word is [by] and neighbours:
# 		replaced
# 		in
# 		the
# 		pollen
# 		record
# 		hazels
# 		brambles
# 		grasses
# 		and
# 		nettles
# Batch number 5:
# 	Central word is [three] and neighbours:
# 		three
# 		one
# 		in
# 		practice
# 		x
# 		one
# 		was
# 		only
# 		commercially
# 		implemented
# 	Central word is [largely] and neighbours:
# 		first
# 		baseman
# 		s
# 		job
# 		consists
# 		of
# 		making
# 		force
# 		plays
# 		at
# 	Central word is [one] and neighbours:
# 		tolstoy
# 		is
# 		widely
# 		regarded
# 		as
# 		of
# 		the
# 		greatest
# 		of
# 		all
# 	Central word is [eight] and neighbours:
# 		soprano
# 		b
# 		one
# 		nine
# 		zero
# 		two
# 		zero
# 		zero
# 		five
# 		james
# 	Central word is [intestinal] and neighbours:
# 		symptoms
# 		may
# 		be
# 		due
# 		to
# 		wall
# 		damage
# 		known
# 		as
# 		leaky
# 	Central word is [reduced] and neighbours:
# 		states
# 		of
# 		particle
# 		b
# 		this
# 		density
# 		matrix
# 		unlike
# 		the
# 		original
# 	Central word is [have] and neighbours:
# 		voyage
# 		on
# 		a
# 		daily
# 		basis
# 		only
# 		a
# 		two
# 		three
# 		hour
# 	Central word is [to] and neighbours:
# 		isthmus
# 		to
# 		create
# 		a
# 		seaway
# 		allow
# 		ship
# 		traffic
# 		between
# 		the
# 	Central word is [and] and neighbours:
# 		approach
# 		having
# 		its
# 		own
# 		advantages
# 		disadvantages
# 		of
# 		course
# 		most
# 		modern
# 	Central word is [of] and neighbours:
# 		customarily
# 		from
# 		among
# 		the
# 		college
# 		cardinals
# 		since
# 		the
# 		catholic
# 		episcopate
# Batch number 6:
# 	Central word is [turks] and neighbours:
# 		growing
# 		power
# 		of
# 		the
# 		seljuk
# 		in
# 		asia
# 		minor
# 		who
# 		had
# 	Central word is [as] and neighbours:
# 		different
# 		vertices
# 		to
# 		represent
# 		them
# 		being
# 		part
# 		of
# 		the
# 		same
# 	Central word is [derived] and neighbours:
# 		deity
# 		maponos
# 		similarly
# 		modron
# 		is
# 		from
# 		common
# 		brythonic
# 		and
# 		gaulish
# 	Central word is [his] and neighbours:
# 		point
# 		of
# 		view
# 		first
# 		opened
# 		eyes
# 		to
# 		the
# 		true
# 		character
# 	Central word is [one] and neighbours:
# 		adopted
# 		until
# 		the
# 		revolutions
# 		of
# 		eight
# 		four
# 		eight
# 		in
# 		france
# 	Central word is [and] and neighbours:
# 		late
# 		two
# 		zero
# 		zero
# 		three
# 		early
# 		two
# 		zero
# 		zero
# 		four
# 	Central word is [him] and neighbours:
# 		superman
# 		with
# 		kryptonite
# 		after
# 		lulling
# 		by
# 		pretending
# 		to
# 		go
# 		straight
# 	Central word is [could] and neighbours:
# 		be
# 		disproved
# 		if
# 		a
# 		method
# 		be
# 		exhibited
# 		which
# 		is
# 		universally
# 	Central word is [the] and neighbours:
# 		most
# 		controversial
# 		policy
# 		decisions
# 		of
# 		last
# 		century
# 		in
# 		canada
# 		on
# 	Central word is [the] and neighbours:
# 		to
# 		obtain
# 		the
# 		information
# 		from
# 		system
# 		rather
# 		than
# 		asking
# 		the
# Batch number 7:
# 	Central word is [one] and neighbours:
# 		history
# 		from
# 		the
# 		google
# 		website
# 		eight
# 		seven
# 		eight
# 		births
# 		one
# 	Central word is [what] and neighbours:
# 		the
# 		inclusion
# 		of
# 		fiction
# 		in
# 		was
# 		supposed
# 		to
# 		be
# 		a
# 	Central word is [story] and neighbours:
# 		can
# 		be
# 		found
# 		in
# 		the
# 		of
# 		john
# 		woodger
# 		at
# 		seahouses
# 	Central word is [by] and neighbours:
# 		very
# 		small
# 		petals
# 		almost
# 		hidden
# 		the
# 		long
# 		stamens
# 		and
# 		are
# 	Central word is [connection] and neighbours:
# 		record
# 		he
# 		was
# 		a
# 		key
# 		between
# 		the
# 		former
# 		corporal
# 		hitler
# 	Central word is [world] and neighbours:
# 		nine
# 		two
# 		seven
# 		when
# 		the
# 		screamed
# 		one
# 		nine
# 		two
# 		eight
# 	Central word is [zero] and neighbours:
# 		the
# 		six
# 		eight
# 		zero
# 		six
# 		and
# 		was
# 		used
# 		mostly
# 		as
# 	Central word is [several] and neighbours:
# 		an
# 		extract
# 		is
# 		quoted
# 		on
# 		web
# 		sites
# 		burgess
# 		anthony
# 		one
# 	Central word is [that] and neighbours:
# 		those
# 		two
# 		words
# 		to
# 		imply
# 		the
# 		scientific
# 		community
# 		s
# 		attachment
# 	Central word is [one] and neighbours:
# 		nine
# 		six
# 		misn
# 		zero
# 		five
# 		three
# 		maxwell
# 		s
# 		equations
# 		electricity
# Batch number 8:
# 	Central word is [granite] and neighbours:
# 		the
# 		igneous
# 		dykes
# 		cutting
# 		the
# 		are
# 		a
# 		small
# 		number
# 		composed
# 	Central word is [source] and neighbours:
# 		eight
# 		two
# 		zero
# 		an
# 		important
# 		event
# 		for
# 		herman
# 		melville
# 		s
# 	Central word is [useful] and neighbours:
# 		redshift
# 		infrared
# 		searches
# 		are
# 		more
# 		for
# 		finding
# 		more
# 		distant
# 		higher
# 	Central word is [van] and neighbours:
# 		iraq
# 		al
# 		faw
# 		peninsula
# 		frans
# 		anraat
# 		mostafa
# 		chamran
# 		minister
# 		of
# 	Central word is [seven] and neighbours:
# 		to
# 		stickball
# 		was
# 		in
# 		one
# 		two
# 		nine
# 		by
# 		a
# 		jesuit
# 	Central word is [of] and neighbours:
# 		allowed
# 		the
# 		caucasian
# 		owners
# 		managers
# 		the
# 		island
# 		have
# 		favored
# 		the
# 	Central word is [is] and neighbours:
# 		second
# 		gamma
# 		m
# 		c
# 		two
# 		the
# 		total
# 		energy
# 		of
# 		the
# 	Central word is [has] and neighbours:
# 		of
# 		close
# 		contact
# 		once
# 		someone
# 		been
# 		infected
# 		with
# 		the
# 		disease
# 	Central word is [iron] and neighbours:
# 		time
# 		demand
# 		for
# 		high
# 		quality
# 		was
# 		dramatically
# 		increasing
# 		to
# 		keep
# 	Central word is [the] and neighbours:
# 		originate
# 		in
# 		the
# 		lower
# 		reaches
# 		river
# 		is
# 		the
# 		sole
# 		habitat
# Batch number 9:
# 	Central word is [his] and neighbours:
# 		to
# 		prove
# 		he
# 		abandoned
# 		it
# 		most
# 		significant
# 		achievements
# 		came
# 		from
# 	Central word is [ends] and neighbours:
# 		individual
# 		to
# 		pursue
# 		his
# 		own
# 		the
# 		state
# 		ensures
# 		that
# 		the
# 	Central word is [later] and neighbours:
# 		time
# 		and
# 		atomic
# 		time
# 		was
# 		defined
# 		as
# 		follows
# 		one
# 		nine
# 	Central word is [due] and neighbours:
# 		it
# 		is
# 		preferred
# 		to
# 		iodine
# 		to
# 		its
# 		much
# 		lower
# 		cost
# 	Central word is [my] and neighbours:
# 		caprino
# 		could
# 		be
# 		beneficial
# 		to
# 		intellectual
# 		development
# 		said
# 		rambousek
# 		as
# 	Central word is [written] and neighbours:
# 		a
# 		doctrine
# 		of
# 		fascism
# 		was
# 		by
# 		giovanni
# 		gentile
# 		a
# 		neo
# 	Central word is [after] and neighbours:
# 		the
# 		removal
# 		of
# 		the
# 		tsars
# 		a
# 		series
# 		of
# 		famine
# 		and
# 	Central word is [on] and neighbours:
# 		of
# 		this
# 		unorthodox
# 		view
# 		based
# 		the
# 		textual
# 		researches
# 		of
# 		raymond
# 	Central word is [the] and neighbours:
# 		r
# 		egion
# 		which
# 		part
# 		of
# 		body
# 		is
# 		affected
# 		s
# 		everity
# 	Central word is [adversus] and neighbours:
# 		begin
# 		adversus
# 		such
# 		as
# 		irenaeus
# 		haeresis
# 		the
# 		christian
# 		writers
# 		inherited
# Batch number 10:
# 	Central word is [and] and neighbours:
# 		medicalisation
# 		of
# 		human
# 		thought
# 		processes
# 		an
# 		increasing
# 		tendency
# 		on
# 		the
# 	Central word is [nine] and neighbours:
# 		zero
# 		two
# 		and
# 		talley
# 		one
# 		eight
# 		six
# 		another
# 		extremely
# 		popular
# 	Central word is [one] and neighbours:
# 		especially
# 		important
# 		eb
# 		one
# 		nine
# 		one
# 		the
# 		dorian
# 		invasion
# 		was
# 	Central word is [s] and neighbours:
# 		atom
# 		transuranium
# 		element
# 		references
# 		kenneth
# 		krane
# 		introductory
# 		nuclear
# 		physics
# 		one
# 	Central word is [two] and neighbours:
# 		stations
# 		fm
# 		one
# 		four
# 		shortwave
# 		one
# 		nine
# 		nine
# 		eight
# 		radios
# 	Central word is [outward] and neighbours:
# 		in
# 		the
# 		manner
# 		in
# 		which
# 		conditions
# 		have
# 		taken
# 		shape
# 		after
# 	Central word is [nfl] and neighbours:
# 		four
# 		zero
# 		t
# 		two
# 		nd
# 		west
# 		one
# 		nine
# 		three
# 		eight
# 	Central word is [a] and neighbours:
# 		local
# 		hero
# 		and
# 		next
# 		to
# 		statue
# 		on
# 		the
# 		grote
# 		markt
# 	Central word is [of] and neighbours:
# 		g
# 		a
# 		line
# 		or
# 		paragraph
# 		text
# 		professional
# 		desktop
# 		publishing
# 		applications
# 	Central word is [christians] and neighbours:
# 		the
# 		practices
# 		of
# 		these
# 		local
# 		and
# 		their
# 		lack
# 		of
# 		belief
